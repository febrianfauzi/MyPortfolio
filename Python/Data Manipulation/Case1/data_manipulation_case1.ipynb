# %% [markdown]
# <h3><b>Data Manipulation :</b></h3>
# Case : Menentukan 5 produk dengan penjualan tertinggi berdasarkan kategori furniture dan pada periode 2018

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("D:/Program/Python/Data Manipulation/superstore_data.xlsx", sheet_name="train")

# %%
df.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data1 = pd.DataFrame(\
    #Filter data berdasarkan kategori furniture dan order pada periode 2018
    df[(df['Category']=='Furniture') &\
        ((df['Order Date'] >= '2018-01-01') & (df['Order Date'] <= '2018-12-31'))])\
        .groupby('Product Name')['Sales']\
        .sum()\
        .sort_values(ascending=False)\
        .reset_index(name='Sales_2018')\
        .head(5)

data1
# Out:
#                                         Product Name  Sales_2018
# 0       HON 5400 Series Task Chairs for Big and Tall    7220.094
# 1      Global Troy Executive Leather Low-Back Tilter    4659.114
# 2  Hon 4070 Series Pagoda Armless Upholstered Sta...    4346.777
# 3  Chromcraft Bull-Nose Wood Oval Conference Tabl...    3636.468
# 4  Global Adaptabilites Bookcase, Cherry/Storm Gr...    3447.840

# %%
#Sort data yang akan digunakan pada grafik
data1.sort_values(\
    by='Sales_2018',\
    ascending=True,\
    inplace=True)

# %%
#Grafik
data1.plot(x='Product Name',
           y=['Sales_2018'],
          kind='barh',
          grid= True,
          xlabel = 'Sales',
          ylabel = 'Product Name',
          figsize= (15,4),
          rot = 0,
          title = 'TOP 5 PRODUCT')
# Out:
# <Axes: title={'center': 'TOP 5 PRODUCT'}, xlabel='Sales', ylabel='Product Name'>
